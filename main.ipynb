# %% [markdown]
# # Test2

# %%
from main import C, main, multi

# %%
c = C()
c.print_list(12)
# Out:
# [1, 2, 3, 12, 1, 2, 3, 12]
# [2, 4, 6, 24]
# [2, 4, 6, 24]

# %%
main()
# Out:
# A  B
# 0  1  a
# 1  2  b
# 2  3  c
# [4 5 6 7]
# [1, 2, 3, 5, 1, 2, 3, 5]
# [2, 4, 6, 10]
# [2, 4, 6, 10]
# c.df.iloc[0:2]:
#    A  B
# 0  1  a
# 1  2  b
# c.df.loc[0:2]:
#    A  B
# 0  1  a
# 1  2  b
# 2  3  c

# %%
# %%timeit
c.df['B'].apply(lambda x: x.upper())
# Out:
# 171 µs ± 19.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit
c.df['B'].str.upper()
# Out:
# 113 µs ± 823 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
c.df['B'].apply(lambda x: x.upper())
# Out:
# 0    A
# 1    B
# 2    C
# Name: B, dtype: object

# %%
c.df['B'].str.upper()
# Out:
# 0    A
# 1    B
# 2    C
# Name: B, dtype: object

# %%
# %%timeit
multi(how='other', n=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b3841e2024cd> in <module>
# ----> 1 get_ipython().run_cell_magic('timeit', '', "multi(how='other', n=100000)\n")
#
# c:\Users\sjoerdermshaus\Documents\vs\test\.venv\lib\site-packages\IPython\core\interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2350             with self.builtin_trap:
#    2351                 args = (magic_arg_s, cell)
# -> 2352                 result = fn(*args, **kwargs)
#    2353             return result
#    2354
#
# <c:\Users\sjoerdermshaus\Documents\vs\test\.venv\lib\site-packages\decorator.py:decorator-gen-61> in timeit(self, line, cell, local_ns)
#
# c:\Users\sjoerdermshaus\Documents\vs\test\.venv\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# ...

# %%
# %%timeit
multi(how='starmap', n=100000, ncpus=4)
